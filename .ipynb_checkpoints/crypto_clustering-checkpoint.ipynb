# %% [markdown]
# # Clustering Crypto

# %%
# Initial imports
import pandas as pd
import hvplot.pandas
from path import Path
import plotly.express as px
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %% [markdown]
# ### Deliverable 1: Preprocessing the Data for PCA

# %%
# Load in the data set.
file = 'crypto_data.csv'
crypto_df = pd.read_csv(file)
crypto_df
# Out:
#      Unnamed: 0        CoinName Algorithm  IsTrading ProofType  \
# 0            42         42 Coin    Scrypt       True   PoW/PoS
# 1           365         365Coin       X11       True   PoW/PoS
# 2           404         404Coin    Scrypt       True   PoW/PoS
# 3           611       SixEleven   SHA-256       True       PoW
# 4           808             808   SHA-256       True   PoW/PoS
# ...         ...             ...       ...        ...       ...
# 1247        XBC     BitcoinPlus    Scrypt       True       PoS
# 1248       DVTC      DivotyCoin    Scrypt      False   PoW/PoS
# 1249       GIOT     Giotto Coin    Scrypt      False   PoW/PoS
# 1250       OPSC  OpenSourceCoin   SHA-256      False   PoW/PoS
# 1251       PUNK       SteamPunk       PoS      False       PoS
#
#       TotalCoinsMined TotalCoinSupply
# 0        4.199995e+01              42
# 1                 NaN      2300000000
# 2        1.055185e+09       532000000
# 3                 NaN          611000
# ...

# %%
# Keep all the cryptocurrencies that are being traded.
clean_crypto_df = crypto_df.drop(crypto_df[crypto_df['IsTrading'] == False].index)

shape = clean_crypto_df.shape[0]
print(shape)
clean_crypto_df
# Out:
# 1144
#      Unnamed: 0     CoinName    Algorithm  IsTrading ProofType  \
# 0            42      42 Coin       Scrypt       True   PoW/PoS
# 1           365      365Coin          X11       True   PoW/PoS
# 2           404      404Coin       Scrypt       True   PoW/PoS
# 3           611    SixEleven      SHA-256       True       PoW
# 4           808          808      SHA-256       True   PoW/PoS
# ...         ...          ...          ...        ...       ...
# 1243       SERO   Super Zero       Ethash       True       PoW
# 1244        UOS          UOS      SHA-256       True      DPoI
# 1245        BDX       Beldex  CryptoNight       True       PoW
# 1246        ZEN      Horizen     Equihash       True       PoW
# 1247        XBC  BitcoinPlus       Scrypt       True       PoS
#
#       TotalCoinsMined TotalCoinSupply
# 0        4.199995e+01              42
# 1                 NaN      2300000000
# 2        1.055185e+09       532000000
# 3                 NaN          611000
# ...

# %%
# Keep all the cryptocurrencies that have a working algorithm.
# Possible error in the assignment - no column suggests a working or non-working algorithm

# %%
# Remove the "IsTrading" column. 
all_crypto_df = clean_crypto_df[['Unnamed: 0', 'CoinName', 'Algorithm', 'ProofType', 'TotalCoinsMined', 'TotalCoinSupply']]
clean_shape = clean_crypto_df.shape[0]
print(clean_shape)
all_crypto_df
# Out:
# 1144
#      Unnamed: 0     CoinName    Algorithm ProofType  TotalCoinsMined  \
# 0            42      42 Coin       Scrypt   PoW/PoS     4.199995e+01
# 1           365      365Coin          X11   PoW/PoS              NaN
# 2           404      404Coin       Scrypt   PoW/PoS     1.055185e+09
# 3           611    SixEleven      SHA-256       PoW              NaN
# 4           808          808      SHA-256   PoW/PoS     0.000000e+00
# ...         ...          ...          ...       ...              ...
# 1243       SERO   Super Zero       Ethash       PoW              NaN
# 1244        UOS          UOS      SHA-256      DPoI              NaN
# 1245        BDX       Beldex  CryptoNight       PoW     9.802226e+08
# 1246        ZEN      Horizen     Equihash       PoW     7.296538e+06
# 1247        XBC  BitcoinPlus       Scrypt       PoS     1.283270e+05
#
#      TotalCoinSupply
# 0                 42
# 1         2300000000
# 2          532000000
# 3             611000
# ...

# %%
# Find null values
for column in all_crypto_df.columns:
    print(f'Column {column} has {all_crypto_df[column].isnull().sum()} null values')
# Out:
# Column Unnamed: 0 has 0 null values
# Column CoinName has 0 null values
# Column Algorithm has 0 null values
# Column ProofType has 0 null values
# Column TotalCoinsMined has 459 null values
# Column TotalCoinSupply has 0 null values

# %%
# Remove rows that have at least 1 null value.
all_crypto_df = all_crypto_df.dropna()
all_shape = all_crypto_df.shape[0]
print(all_shape)
all_crypto_df
# Out:
# 685
#      Unnamed: 0     CoinName    Algorithm ProofType  TotalCoinsMined  \
# 0            42      42 Coin       Scrypt   PoW/PoS     4.199995e+01
# 2           404      404Coin       Scrypt   PoW/PoS     1.055185e+09
# 4           808          808      SHA-256   PoW/PoS     0.000000e+00
# 5          1337    EliteCoin          X13   PoW/PoS     2.927942e+10
# 7           BTC      Bitcoin      SHA-256       PoW     1.792718e+07
# ...         ...          ...          ...       ...              ...
# 1238       ZEPH       ZEPHYR      SHA-256      DPoS     2.000000e+09
# 1242        GAP      Gapcoin       Scrypt   PoW/PoS     1.493105e+07
# 1245        BDX       Beldex  CryptoNight       PoW     9.802226e+08
# 1246        ZEN      Horizen     Equihash       PoW     7.296538e+06
# 1247        XBC  BitcoinPlus       Scrypt       PoS     1.283270e+05
#
#      TotalCoinSupply
# 0                 42
# 2          532000000
# 4                  0
# 5       314159265359
# ...

# %%
print(shape)

# %%
# Keep the rows where coins are mined.
mined_crypto_df = all_crypto_df.drop(all_crypto_df[all_crypto_df['TotalCoinsMined'] == 0].index)

mined_shape = mined_crypto_df.shape[0]
print(mined_shape)
mined_crypto_df
# Out:
# 533
#      Unnamed: 0     CoinName    Algorithm ProofType  TotalCoinsMined  \
# 0            42      42 Coin       Scrypt   PoW/PoS     4.199995e+01
# 2           404      404Coin       Scrypt   PoW/PoS     1.055185e+09
# 5          1337    EliteCoin          X13   PoW/PoS     2.927942e+10
# 7           BTC      Bitcoin      SHA-256       PoW     1.792718e+07
# 8           ETH     Ethereum       Ethash       PoW     1.076842e+08
# ...         ...          ...          ...       ...              ...
# 1238       ZEPH       ZEPHYR      SHA-256      DPoS     2.000000e+09
# 1242        GAP      Gapcoin       Scrypt   PoW/PoS     1.493105e+07
# 1245        BDX       Beldex  CryptoNight       PoW     9.802226e+08
# 1246        ZEN      Horizen     Equihash       PoW     7.296538e+06
# 1247        XBC  BitcoinPlus       Scrypt       PoS     1.283270e+05
#
#      TotalCoinSupply
# 0                 42
# 2          532000000
# 5       314159265359
# 7           21000000
# ...

# %%
# Create a new DataFrame that holds only the cryptocurrencies names.
crypto_names_df=mined_crypto_df[['CoinName']]
crypto_names_df
# Out:
#          CoinName
# 0         42 Coin
# 2         404Coin
# 5       EliteCoin
# 7         Bitcoin
# 8        Ethereum
# ...           ...
# 1238       ZEPHYR
# 1242      Gapcoin
# 1245       Beldex
# 1246      Horizen
# 1247  BitcoinPlus
#
# [533 rows x 1 columns]

# %%
# Drop the 'CoinName' column since it's not going to be used on the clustering algorithm.
mined_crypto_df.drop(columns=['CoinName'], inplace=True)
mined_crypto_df
# Out:
#      Unnamed: 0    Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0            42       Scrypt   PoW/PoS     4.199995e+01              42
# 2           404       Scrypt   PoW/PoS     1.055185e+09       532000000
# 5          1337          X13   PoW/PoS     2.927942e+10    314159265359
# 7           BTC      SHA-256       PoW     1.792718e+07        21000000
# 8           ETH       Ethash       PoW     1.076842e+08               0
# ...         ...          ...       ...              ...             ...
# 1238       ZEPH      SHA-256      DPoS     2.000000e+09      2000000000
# 1242        GAP       Scrypt   PoW/PoS     1.493105e+07       250000000
# 1245        BDX  CryptoNight       PoW     9.802226e+08      1400222610
# 1246        ZEN     Equihash       PoW     7.296538e+06        21000000
# 1247        XBC       Scrypt       PoS     1.283270e+05         1000000
#
# [533 rows x 5 columns]

# %%
# Make Unnamed: 0 the index
mined_crypto_df.set_index('Unnamed: 0',inplace=True, drop=True)
mined_crypto_df
# Out:
#               Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# Unnamed: 0
# 42               Scrypt   PoW/PoS     4.199995e+01              42
# 404              Scrypt   PoW/PoS     1.055185e+09       532000000
# 1337                X13   PoW/PoS     2.927942e+10    314159265359
# BTC             SHA-256       PoW     1.792718e+07        21000000
# ETH              Ethash       PoW     1.076842e+08               0
# ...                 ...       ...              ...             ...
# ZEPH            SHA-256      DPoS     2.000000e+09      2000000000
# GAP              Scrypt   PoW/PoS     1.493105e+07       250000000
# BDX         CryptoNight       PoW     9.802226e+08      1400222610
# ZEN            Equihash       PoW     7.296538e+06        21000000
# XBC              Scrypt       PoS     1.283270e+05         1000000
#
# [533 rows x 4 columns]

# %%
# Use get_dummies() to create variables for text features.
X = pd.get_dummies(mined_crypto_df, columns=['Algorithm', 'ProofType'])
X
# Out:
#             TotalCoinsMined TotalCoinSupply  Algorithm_1GB AES Pattern Search  \
# Unnamed: 0
# 42             4.199995e+01              42                                 0
# 404            1.055185e+09       532000000                                 0
# 1337           2.927942e+10    314159265359                                 0
# BTC            1.792718e+07        21000000                                 0
# ETH            1.076842e+08               0                                 0
# ...                     ...             ...                               ...
# ZEPH           2.000000e+09      2000000000                                 0
# GAP            1.493105e+07       250000000                                 0
# BDX            9.802226e+08      1400222610                                 0
# ZEN            7.296538e+06        21000000                                 0
# XBC            1.283270e+05         1000000                                 0
#
# ...

# %%
# Standardize the data with StandardScaler().
data_scaler = StandardScaler()
X = data_scaler.fit_transform(X)

# %% [markdown]
# ### Deliverable 2: Reducing Data Dimensions Using PCA

# %%
# Using PCA to reduce dimension to three principal components.
# YOUR CODE HERE

# %%
# Create a DataFrame with the three principal components.
# YOUR CODE HERE

# %% [markdown]
# ### Deliverable 3: Clustering Crytocurrencies Using K-Means
#
# #### Finding the Best Value for `k` Using the Elbow Curve

# %%
# Create an elbow curve to find the best value for K.
# YOUR CODE HERE

# %% [markdown]
# Running K-Means with `k=4`

# %%
# Initialize the K-Means model.
# YOUR CODE HERE

# Fit the model
# YOUR CODE HERE

# Predict clusters
# YOUR CODE HERE

# %%
# Create a new DataFrame including predicted clusters and cryptocurrencies features.
# Concatentate the crypto_df and pcs_df DataFrames on the same columns.
# YOUR CODE HERE

#  Add a new column, "CoinName" to the clustered_df DataFrame that holds the names of the cryptocurrencies. 
# YOUR CODE HERE

#  Add a new column, "Class" to the clustered_df DataFrame that holds the predictions.
# YOUR CODE HERE

# Print the shape of the clustered_df
print(clustered_df.shape)
clustered_df.head(10)

# %% [markdown]
# ### Deliverable 4: Visualizing Cryptocurrencies Results
#
# #### 3D-Scatter with Clusters

# %%
# Creating a 3D-Scatter with the PCA data and the clusters
# YOUR CODE HERE

# %%
# Create a table with tradable cryptocurrencies.
# YOUR CODE HERE

# %%
# Print the total number of tradable cryptocurrencies.
# YOUR CODE HERE

# %%
# Scaling data to create the scatter plot with tradable cryptocurrencies.
# YOUR CODE HERE

# %%
# Create a new DataFrame that has the scaled data with the clustered_df DataFrame index.
# YOUR CODE HERE

# Add the "CoinName" column from the clustered_df DataFrame to the new DataFrame.
# YOUR CODE HERE

# Add the "Class" column from the clustered_df DataFrame to the new DataFrame. 
# YOUR CODE HERE

plot_df.head(10)

# %%
# Create a hvplot.scatter plot using x="TotalCoinsMined" and y="TotalCoinSupply".
# YOUR CODE HERE
